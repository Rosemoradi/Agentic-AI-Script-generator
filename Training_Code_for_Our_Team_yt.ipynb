# %% [markdown]
# **1. Imports**

# %% [markdown]
# Let's start with imports and installing Hugging Face datasets.

# %%
# !pip install datasets
# Out:
# Requirement already satisfied: datasets in /usr/local/lib/python3.11/dist-packages (3.4.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from datasets) (3.18.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from datasets) (2.0.2)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.11/dist-packages (from datasets) (18.1.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.11/dist-packages (from datasets) (0.3.8)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from datasets) (2.2.2)
# Requirement already satisfied: requests>=2.32.2 in /usr/local/lib/python3.11/dist-packages (from datasets) (2.32.3)
# Requirement already satisfied: tqdm>=4.66.3 in /usr/local/lib/python3.11/dist-packages (from datasets) (4.67.1)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.11/dist-packages (from datasets) (3.5.0)
# Requirement already satisfied: multiprocess<0.70.17 in /usr/local/lib/python3.11/dist-packages (from datasets) (0.70.16)
# Requirement already satisfied: fsspec<=2024.12.0,>=2023.1.0 in /usr/local/lib/python3.11/dist-packages (from fsspec[http]<=2024.12.0,>=2023.1.0->datasets) (2024.12.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.11/dist-packages (from datasets) (3.11.14)
# Requirement already satisfied: huggingface-hub>=0.24.0 in /usr/local/lib/python3.11/dist-packages (from datasets) (0.29.3)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from datasets) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from datasets) (6.0.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (6.2.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (0.3.0)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (1.18.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.24.0->datasets) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets) (2025.1.31)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets) (2025.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.17.0)

# %%
import torch
import numpy as np
from transformers import AutoTokenizer, Trainer, TrainingArguments, DataCollatorForLanguageModeling, AutoModelForCausalLM
from datasets import load_dataset, concatenate_datasets, Dataset, DatasetDict
from peft import LoraConfig, get_peft_model, TaskType
import matplotlib.pyplot as plt
import random
import os

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")
# Out:
# Using device: cuda

# %% [markdown]
# **2. Tokenization and Data Blocks**

# %% [markdown]
# Let's access our .txt files from Google Drive and prepare them with the tokenzier.
#
# *   Step 1. Read all files as a concatenated text and Tokenize everything.
# *   Step 2. Create blocks of data from the one long piece of tokens.
# *   Step 3. Make Hugging Face dataset.

# %%
# mount Google Drive
from google.colab import drive
drive.mount('/content/drive')

# set up tokenizer
tokenizer = AutoTokenizer.from_pretrained("gpt2-medium", use_fast=True)
tokenizer.pad_token = tokenizer.eos_token
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# ---------Saber's path--------------

# # read and tokenize each file
# def load_and_tokenize(file_path):
#     with open(file_path, 'r', encoding='utf-8') as f:
#         text = f.read()
#     tokenized = tokenizer(text)
#     return tokenized['input_ids']

# # specify file path in Google Drive
# data_path = "/content/drive/MyDrive/SEP775NLP_Final_Project/Friends_script/"

# # run the function above to tokenize the data
# train_ids = load_and_tokenize(f"{data_path}/train_data.txt")
# val_ids = load_and_tokenize(f"{data_path}/val_data.txt")
# test_ids = load_and_tokenize(f"{data_path}/test_data.txt")
# general_test_ids = load_and_tokenize(f"{data_path}/wikitext103_test.txt")

# %%
# ---------Rose's path--------------

# # read and tokenize each file
# def load_and_tokenize(file_path):
#     with open(file_path, 'r', encoding='utf-8') as f:
#         text = f.read()
#     tokenized = tokenizer(text)
#     return tokenized['input_ids']

# # specify file path in Google Drive
# data_path = "/content/drive/MyDrive/datasets/"

# # run the function above to tokenize the data
# train_ids = load_and_tokenize(f"{data_path}/train_data.txt")
# val_ids = load_and_tokenize(f"{data_path}/val_data.txt")
# test_ids = load_and_tokenize(f"{data_path}/test_data.txt")
# general_test_ids = load_and_tokenize(f"{data_path}/wikitext103_test.txt")

# %%
# ---------Yingtao's path--------------

# read and tokenize each file
def load_and_tokenize(file_path):
    with open(file_path, 'r', encoding='utf-8') as f:
        text = f.read()
    tokenized = tokenizer(text)
    return tokenized['input_ids']

# specify file path in Google Drive
data_path = "/content/drive/MyDrive/NLP/datas/"

# run the function above to tokenize the data
train_ids = load_and_tokenize(f"{data_path}/train_data.txt")
val_ids = load_and_tokenize(f"{data_path}/val_data.txt")
test_ids = load_and_tokenize(f"{data_path}/test_data.txt")
general_test_ids = load_and_tokenize(f"{data_path}/wikitext103_test.txt")
# Out:
# Token indices sequence length is longer than the specified maximum sequence length for this model (1077787 > 1024). Running this sequence through the model will result in indexing errors

# %%
# create blocks of sequences
def create_blocks(all_tokens, block_size=512):
  blocks = []
  # loop through all of the tokens, split them by block_size
  for i in range(0, len(all_tokens), block_size):
    tokens_in_this_block = all_tokens[i:i+block_size] # takes [0:512], then [512:1024]...
    blocks.append(tokens_in_this_block)
  return blocks # returns a list of list of blocks

# run the function above to create the data blocks
train_blocks = create_blocks(train_ids)
val_blocks = create_blocks(val_ids)
test_blocks = create_blocks(test_ids)
general_test_blocks = create_blocks(general_test_ids)

# verify that one block contains multiple lines of the script
print(train_blocks[0])
# Out:
# [464, 1881, 2080, 262, 520, 12004, 13145, 198, 25354, 416, 25, 5502, 3469, 5714, 1222, 5502, 42971, 628, 198, 58, 36542, 25, 5694, 2448, 74, 11, 15984, 318, 7351, 26154, 11, 9847, 11, 290, 23240, 511, 11758, 8183, 198, 198, 44045, 25, 357, 1462, 26154, 8, 19443, 13, 357, 39, 1746, 340, 284, 683, 2014, 198, 198, 19585, 88, 25, 6952, 345, 13, 198, 198, 44045, 25, 357, 1462, 9847, 8, 327, 1324, 18863, 2879, 13, 357, 39, 1746, 340, 284, 683, 2014, 198, 198, 38328, 25, 402, 3247, 494, 13, 198, 198, 44045, 25, 843, 257, 3621, 3024, 36930, 329, 23240, 13, 357, 39, 1746, 340, 284, 607, 2014, 198, 198, 9069, 3970, 25, 317, 1383, 11, 5875, 345, 13, 357, 3673, 1063, 1223, 2014, 28574, 371, 620, 30, 198, 198, 44045, 25, 9425, 30, 198, 198, 9069, 3970, 25, 4162, 857, 616, 269, 259, 16487, 4859, 423, 281, 1931, 6005, 30, 198, 198, 44045, 25, 3966, 0, 1320, 338, 1521, 13, 357, 44045, 8794, 2157, 607, 1027, 11, 290, 7228, 257, 269, 259, 16487, 4859, 2014, 314, 1101, 7926, 0, 198, 198, 7, 3347, 2753, 262, 21613, 503, 286, 23240, 338, 6891, 290, 23240, 7584, 607, 6508, 866, 287, 16234, 2014, 198, 198, 43093, 29501, 198, 58, 36542, 25, 28346, 338, 1693, 11, 28346, 318, 19720, 1366, 656, 465, 3644, 11, 339, 7622, 19720, 772, 981, 2263, 257, 4144, 286, 6891, 351, 530, 1021, 13, 1881, 286, 465, 763, 12, 22896, 11114, 416, 8183, 198, 198, 48081, 25, 28346, 13, 198, 198, 1925, 392, 1754, 25, 9074, 13, 11396, 5354, 13, 921, 821, 2045, 14081, 1909, 13, 843, 743, 314, 910, 11, 326, 318, 257, 845, 48259, 23179, 4129, 319, 345, 13, 198, 198, 27034, 13, 11396, 5354, 25, 3363, 13, 3894, 11, 1770, 13, 509, 455, 417, 624, 3382, 345, 284, 2245, 416, 465, 2607, 379, 262, 886, 286, 262, 1110, 13, 198, 198, 1925, 392, 1754, 25, 3966, 11, 6004, 13, 1002, 428, 318, 546, 883, 33401, 44940, 11, 314, 550, 2147, 284, 466, 351, 606, 13, 16123, 13, 10528, 379, 477, 13, 16123, 13, 357, 1925, 392, 1754, 8404, 284, 7808, 257, 14239, 9015, 422, 262, 2415, 2014, 10528, 13, 198, 198, 58, 36542, 25, 5694, 2448, 74, 11, 2506, 318, 612, 475, 28346, 13, 1380, 2577, 1350, 4539, 287, 11, 6568, 306, 8183, 198, 198, 2725, 2577, 1350, 25, 14690, 345, 3730, 0, 28346, 338, 2406, 290, 339, 1139, 339, 468, 11, 588, 11, 428, 8082, 1705, 11, 523, 618, 339, 3011, 994, 11, 356, 714, 477, 719, 588, 11, 345, 760, 986, 198, 198, 7, 1925, 392, 1754, 2058, 287, 2014, 198, 198, 1925, 392, 1754, 25, 14690, 0, 198, 198, 3237, 25, 14690, 0, 198, 198, 2725, 2577, 1350, 25, 7236, 2000, 13, 887, 340, 373, 1016, 284, 307, 1107, 922, 13, 198, 198, 38328, 25, 1867, 338, 1016, 319, 30, 198, 198, 3237, 25, 1867, 318, 340, 30, 198, 198, 1925, 392, 1754, 25, 1406, 11, 340, 338, 257, 7226, 1110, 379, 670, 13, 314, 1101, 5128, 889, 616, 3146, 11, 290, 1263]

# %%
# make dictionaries and then turn them into hugging face datasets
train_dataset = Dataset.from_dict({"input_ids": train_blocks})
val_dataset = Dataset.from_dict({"input_ids": val_blocks})
test_dataset = Dataset.from_dict({"input_ids": test_blocks})
general_test_dataset = Dataset.from_dict({"input_ids": general_test_blocks})

# create the Hugging Face dataset dict
dataset_dict = DatasetDict({"train": train_dataset, "validation": val_dataset, "test": test_dataset,
                            "general_test": general_test_dataset})

# %%
train_dataset = dataset_dict["train"].shuffle(seed=42).select(range(2000))  # 只使用 1000 条数据
eval_dataset = dataset_dict["validation"].shuffle(seed=42).select(range(200))  # 只使用 200 条数据

# %%
# set up data collator
data_collator = DataCollatorForLanguageModeling(tokenizer=tokenizer, mlm=False)  # For causal LM

# %% [markdown]
# **3. Model Training**

# %% [markdown]
# Let's set up the parameters for training here. We will also benchmark the pre-trained model's ability on a general Wiki language dataset (before fine-tuning). We will test the model again on this dataset after fine-tuning to see if our model retains the general language capability.

# %%
# access the model from Hugging Face
#model = AutoModelForCausalLM.from_pretrained("gpt2-medium") # or use "deepseek-ai/deepseek-coder-1.3b-instruct"

local_model_path = "/content/drive/MyDrive/SEP775NLP_Final_Project/Models/gpt2_335m_lorar8"
model = AutoModelForCausalLM.from_pretrained("gpt2-medium")
model.save_pretrained(local_model_path)
model = AutoModelForCausalLM.from_pretrained(local_model_path)

model.config.pad_token_id = model.config.eos_token_id

# --------------------------------------------------------------------------------(comment this section out if running without LoRA)
# freeze all the weights
for param in model.parameters():
    param.requires_grad = False
# -------------------------------------------------------------------------------- (this code might not be needed even when running LoRa, but just in case)

# %%
# # set up dummy trainer to benchmark the pre-trained model's capability on the general wiki test set
# dummy_training_args = TrainingArguments(output_dir="./eval_output", do_train=False, per_device_eval_batch_size=4, report_to="none")
# dummy_trainer = Trainer(model=model, args=dummy_training_args, eval_dataset=dataset_dict["general_test"], data_collator=data_collator)

# # test the pre-trained model
# benchmark_general_eval_results = dummy_trainer.evaluate(dataset_dict["general_test"])
# print(f"General Wiki Data before Fine-Tuning: eval_loss = {benchmark_general_eval_results['eval_loss']:.2f}")

# %%
# # --------------------------------------------------------------------------------(comment this section out if running without LoRA)
# # setup LoRA configuration and wrap the model with it
# lora_config = LoraConfig(r=8, lora_alpha=32, lora_dropout=0.05, bias="none", task_type=TaskType.CAUSAL_LM) # increase r for a more powerful adapter
# model = get_peft_model(model, lora_config)
# model.print_trainable_parameters()# verify we're only training LoRA weights
# # --------------------------------------------------------------------------------
# output_dir = "/content/drive/MyDrive/SEP775NLP_Final_Project/Models/gpt2_335m_lorar8"
# # set up training_args
# training_args = TrainingArguments(output_dir=output_dir, # Rose: "/content/drive/MyDrive/datasets"
#                                   evaluation_strategy="epoch",
#                                   save_strategy="epoch",
#                                   num_train_epochs=3,
#                                   per_device_train_batch_size=8,
#                                   per_device_eval_batch_size=8,
#                                   learning_rate=3e-5,
#                                   #save_steps=2000, (this is disabled beacuse the checkpoints took too much space in Google Dirve)
#                                   logging_steps=500,
#                                   save_total_limit=1,
#                                   resume_from_checkpoint=True,
#                                   load_best_model_at_end=True,
#                                   metric_for_best_model="eval_loss",
#                                   weight_decay=0.01, # added regularization
#                                   warmup_steps=1, # added lr scheduler and warmup
#                                   lr_scheduler_type="linear",
#                                   push_to_hub=False,
#                                   report_to=[], )

# # setup trainer
# trainer = Trainer(model=model,
#                   args=training_args,
#                   train_dataset=train_dataset,
#                   eval_dataset=eval_dataset,
#                   data_collator=data_collator)

# %%
# # start training
# trainer.train()

# %% [markdown]
# **4. Evaluation**

# %% [markdown]
# Take the trained model, and evaluate its performance on the two different tests sets.
#
# *   Test 1. Unseen FRIENDS scripts - to test model's ability to pick up the specific style of the show.
# *   Test 2. General Wiki English data - to test model's general language capabilities. (compare to benchmark)

# %%
# # evaluation process
# eval_results = trainer.evaluate(dataset_dict["test"])
# general_eval_results = trainer.evaluate(dataset_dict["general_test"])

# print(f"Unseen FRIENDS scripts: eval_loss = {eval_results['eval_loss']:.2f}")
# print(f"General Wiki Data after Fine-Tuning: eval_loss = {general_eval_results['eval_loss']:.2f}")

# %% [markdown]
# **5. Generation**

# %% [markdown]
# Finally, we'll use this model to generate a new episode to see for ourselves how the model performs. We trialed the following different approaches for text generation and found that better results can be obtained with the last approach, so in this version of the code we only kept that approach.
#
# *   Approach 1. Greedy Search (using argmax)
# *   Approach 2. MultiNomial selection
# *   Approach 3. MultiNomial selection with top_k and top_p filters

# %%
from transformers import pipeline

# load a summarization model
summarizer = pipeline("summarization", model="Falconsai/text_summarization")
# Out:
# config.json:   0%|          | 0.00/1.49k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/242M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/2.32k [00:00<?, ?B/s]
# spiece.model:   0%|          | 0.00/792k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/2.42M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/2.20k [00:00<?, ?B/s]
# Device set to use cuda:0

# %%
def summarize_long_text(text, max_length=256, summary_max_length=50, summary_min_length=25):
    words = text.split()
    if len(words) <= 10:
        return text


    chunks = [" ".join(words[i:i + max_length]) for i in range(0, len(words), max_length)]


    summaries = []
    for chunk in chunks:
        summary = summarizer(chunk, max_length=summary_max_length, min_length=summary_min_length, do_sample=False)[0]['summary_text']
        summaries.append(summary)


    return " ".join(summaries)

# %%
# create initial prompt and tokenize it
prompt = "The One With McMaster University Party /n Written by: GPT2-medium /n Cohen Produced by: Robert Carlock & Wendy Knoller [Scene: McMaster University Student Center. Rachel and Joey are talking] Joey:"
model_inputs = tokenizer(prompt, return_tensors="pt", return_attention_mask=True).to(model.device)
model.generation_config.pad_token_id = tokenizer.pad_token_id # suppress padding warning

# create a list that holds the prompt, future tokens will be appended into this list later on
all_tokens = model_inputs["input_ids"][0].tolist()

# to avoid hitting memory limits, generate only one batch with the initial prompt, take last few tokens out to generate the next batch.
context_window = 256 # take this many tokens to set up next batch's generation
max_token = 2048
step_size = 256 # generate only 256 new tokens at a time
num_of_loops = int(max_token / step_size)

for i in range(num_of_loops):

  output = model.generate(**model_inputs,
                          max_new_tokens=step_size,
                          do_sample=True,
                          top_k=50, # keep 50 highest probable options
                          top_p=0.9, # keep only the options that add up to p% probability, filter out the remaining less probable options
                          temperature=1) # to add a little bit more creativity if needed

  output_tokens = output[0].tolist()

  new_tokens = output_tokens[-step_size:] # get rid of the previous context and keep only new tokens
  all_tokens.extend(new_tokens) # and place those tokens into the list


  #current_text = tokenizer.decode(all_tokens, skip_special_tokens=True)
  #summary = summarize_long_text(current_text)
  # new_prompt = summary
  # model_inputs = tokenizer(new_prompt, return_tensors="pt", return_attention_mask=True).to(model.device)


  previous_context = output_tokens[-context_window:] # set new previous_context for next loop
  previous_context_tensor = torch.tensor([previous_context]).to(model.device) # prepare the inputs and attention mask for next loop
  attention_mask = (previous_context_tensor != tokenizer.pad_token_id).long()
  model_inputs = {"input_ids": previous_context_tensor, "attention_mask":attention_mask}



# decode from the list and print results
generated_script = tokenizer.decode(all_tokens, skip_special_tokens=True)
print("-------------------------------------------------------------")
print(generated_script)
# Out:
# -------------------------------------------------------------
# The One With McMaster University Party /n Written by: GPT2-medium /n Cohen Produced by: Robert Carlock & Wendy Knoller [Scene: McMaster University Student Center. Rachel and Joey are talking] Joey: Do you want to know why I'm dating a guy? Rachel: What about? Joey: We don't have time. We don't want to waste it talking. Joey: He's cool, though. Rachel: I mean, he's not like me. He's like an old lady. It's really hard for me to figure out how to be a woman. [Dates. Rachel goes in to check on her date. Joey is still waiting.] Joey: He's cool. Rachel: He's really cool. Joey: Do you think I should date him? Rachel: It's pretty obvious. [They start dating again. They don't start talking until Joey makes some kind of weird remark. Rachel is shocked at the sound of this.] Joey: [to Rachel] How did you know? You didn't ask. Rachel: The only thing that makes me really nervous is that you're a little old. Joey: I didn't know! [They kiss, the wind makes Joey jump.] Joey: [to Rachel] That was my kiss. [Cut to: McMaster University Student Centre. Rachel and Joey are sitting on a bench. Joey is holding a picture of a man.] Joey: [looking at the picture] He's pretty hot. Rachel: Oh, he's hot. Joey: [laughing] It's about a guy. Rachel: Oh. Joey: It's like, two guys kissing. Rachel: [looks at her face] Oh, my God. Joey: [laughing] Yeah. She thinks she is a guy. Joey: Yeah, I do. Joey: I'll get to the girl that's next to you. Rachel: No, I'm not. I mean, I am. [Rachel is embarrassed. Joey doesn't know what to say and walks away. Joey and Rachel kiss again.] Rachel: Oh, no. No. No! What the hell? It's not about her. You don't even know me, do you? I'm not like you! I'm not like you. Why are you telling me this? It's really rude, Joey. Joey: [chuckling] Rachel: I'm not gonna get turned on by you. Joey: Well, what are you so afraid of? That I don't want you? Rachel: I'm not saying I hate you. I'm just saying that if I was the person you wanted to be, you would have been cool with it. Joey: But you're not like me. You don't know me. You don't even like me. Oh, well. That's fine. It's not fair. [Rachel turns away and walks away.] Rachel: Oh my God, I don't know if it's that I'm a little scared to make you feel comfortable. But you seem really nice. Joey: Do you know what? It's not fair. I'm not asking you to kiss me again. Rachel: No, you don't think that is fair. I mean, are you telling me that I'm really afraid to be yourself in front of you? Joey: No. That's the thing. You're not a boy. You don't have to be a boy. Rachel: But I'm not like him. I can do anything I want. It doesn't matter if you're a guy or a girl. [Rachel leaves. Monica and Ross are shocked.] Monica: Joey! Joey: Okay, look. I don't want you to feel sorry for me. I just want you to love me back. [Laughing.] We're going to have our little celebration. Ross: I want you to make us some cookies. You don't have to be a boy to make these. Joey: Yeah. So that's what I'm doing. Now... [Ross takes Joey's hand.] You know, this was really fun. And I think I'd rather be with you now than be around any of this. [They kiss.] Joey: I can't help it. We both know that we're together now. Ross: You don't feel that? You don't feel like you've never been there? Joey: Yeah. [A little breath] We got to do this together. We both know that it's all right to share. You've been waiting for it, and I'm here to make it happen. Ross: That's really good. Joey: We're going to be together forever. Ross: Oh, you'll make me happy, too.
#
# [The boys walk to the girls' room. Monica sits next to Rachel.] Monica: Well, I mean, you're in your thirties. Rachel: I have the best looks and personality in this world, and I'm doing really well for myself. Monica: Do you want me to be your friend or just your friend to be, Rachel? Rachel: I'll do anything for you. You can count on it. Monica: You know, there are times where I need to be in control of myself. I should just give myself to somebody else. Rachel: No, that's really not you. I am who I am. You're not me. You're somebody else. Monica: Well, when someone else wants you, you'll just give them your best shot, okay? Rachel: [thinking] Don't worry. I'm not that kind of person. You know what I'm really not? I'm not attracted to women. I'm really into guys, man. [She leans in close and kisses the guy in front of her. The audience applauds.] What? What? It was so close.
#
# [After the dinner scene at the hotel, Joey is sitting next to Monica, sitting on a sofa watching a movie.] Joey: Okay, I'm ready. Monica: What? [Ross stands up from his chair.] What's wrong? Joey: What did I say? I'm ready for dinner. I just don't know when. Monica: It's over, honey. Now? Joey: Yes. My heart's ready. Monica: You'll love my dinner, sweetheart. I can't wait for you. [He pulls her in, kisses her back.] It's so great to finally meet you.
#
# [Joey is talking to Monica and is being shown the footage of the shooting of "Sugar Daddy", with her saying "Well that was really cute, but really it was a joke." Monica looks embarrassed.] Monica: Why didn't you do that? Joey: So I can't hurt my kid. Monica: But you did do that, and it was cute, right? [They laugh, they're laughing all the way to the airport.] Joey: But what about the parents? Ross: Well, you know who else was really cute, the one that wasn't? The guy that didn't do it at all? The one that did it? Joey: Yeah, who was doing it? Ross: Yeah. He didn't. Joey: Okay, Ross. I'm so sorry about that. Ross: I'm so sorry. I just wanted to tell you... I don't want to hurt my kid. Joey: But, Ross, I'm sorry for hurting your kid. Ross: But not for doing that. Joey: It's not that, I mean if I hurt the kid that's like, all I did was pull the trigger. [They smile at each other, Ross leans in for a kiss.] I never hurt anybody. Ross: Well, I'm sorry, but you had no way to know that. [They kiss again.] Joey: Ross, please, we have to do it right. If you hurt me, we can't do this, we can't do this. [They kiss again.]
#
# Ross: This was the worst thing you've ever done. Monica: It was the best thing, Ross! Ross: It was the best thing that ever happened to me. Monica: You don't understand, Ross. Ross: What? I didn't even do it. Monica: You did it right? Ross: I did not, Monica. I didn't even do that. Monica: No, you did, because you could. Ross: But, Monica, I'm not sure that's what you meant. Monica: I didn't do that, Ross. [Ross looks at his wrist, the pain in his arm is going away.] Ross: I don't think it's something I could do, because I've hurt so many people. Monica: I know, I know, but I thought I was so lucky to have people that I'm happy with. Ross: [Panting] I know I did.
#
# [They sit in a corner at a café eating a plate of pasta.] Joey: You're a great cook. I think your pasta makes up for the fact that you don't like cooking. I think it makes your work life less boring, more exciting. You are, in a way, perfect for your job. If I had it to do over again, I think I would do it all over again. Monica: I don't care. I was so jealous that when we were growing up, I was always told I wasn't talented enough for anything. You had to show up. Joey: But you're like my angel! Monica: You're my angel! Oh boy! I should have never let you do that!
#
# [Ross is waiting for Joey at the bus stop after he gets into the car, leaving] Joey: Wait for me. [They see the two girls walk into the parking lot with the bus and Ross runs up to them] Joey: Look. I want you to call me, too. I know I shouldn't be calling, but there's nothing I can do about you right now. It's like the last few minutes of my life, and I need you to come and comfort me. If you do, then all this is over, and I can talk to you again. You know what I need to

# %%
output_dir = "/content/drive/MyDrive/SEP775NLP_Final_Project/Models/Falconsai"
file_name = "generated_script.txt"
file_path = os.path.join(output_dir, file_name)

os.makedirs(output_dir, exist_ok=True)
with open(file_path, "w") as f:
    f.write(generated_script)
print(f"File saved to: {file_path}")
# Out:
# File saved to: /content/drive/MyDrive/SEP775NLP_Final_Project/Models/Falconsai/generated_script.txt

# %%
# create initial prompt and tokenize it
prompt = "The One With McMaster University Party /n Written by: GPT2-medium /n Cohen Produced by: Robert Carlock & Wendy Knoller [Scene: McMaster University Student Center. Rachel and Joey are talking] Joey:"
model_inputs = tokenizer(prompt, return_tensors="pt", return_attention_mask=True).to(model.device)
model.generation_config.pad_token_id = tokenizer.pad_token_id # suppress padding warning

# create a list that holds the prompt, future tokens will be appended into this list later on
all_tokens = model_inputs["input_ids"][0].tolist()

# to avoid hitting memory limits, generate only one batch with the initial prompt, take last few tokens out to generate the next batch.
context_window = 256 # take this many tokens to set up next batch's generation
max_token = 2048
step_size = 256 # generate only 256 new tokens at a time
num_of_loops = int(max_token / step_size)

for i in range(num_of_loops):

  output = model.generate(**model_inputs,
                          max_new_tokens=step_size,
                          do_sample=True,
                          top_k=50, # keep 50 highest probable options
                          top_p=0.9, # keep only the options that add up to p% probability, filter out the remaining less probable options
                          temperature=1) # to add a little bit more creativity if needed

  output_tokens = output[0].tolist()

  new_tokens = output_tokens[-step_size:] # get rid of the previous context and keep only new tokens
  all_tokens.extend(new_tokens) # and place those tokens into the list


  current_text = tokenizer.decode(all_tokens, skip_special_tokens=True)
  summary = summarize_long_text(current_text)
  new_prompt = summary
  model_inputs = tokenizer(new_prompt, return_tensors="pt", return_attention_mask=True).to(model.device)


  # previous_context = output_tokens[-context_window:] # set new previous_context for next loop
  # previous_context_tensor = torch.tensor([previous_context]).to(model.device) # prepare the inputs and attention mask for next loop
  # attention_mask = (previous_context_tensor != tokenizer.pad_token_id).long()
  # model_inputs = {"input_ids": previous_context_tensor, "attention_mask":attention_mask}



# decode from the list and print results
generated_script_with_summary = tokenizer.decode(all_tokens, skip_special_tokens=True)
print("-------------------------------------------------------------")
print(generated_script_with_summary)
# Out:
# Your max_length is set to 50, but your input_length is only 18. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=9)
# -------------------------------------------------------------
# The One With McMaster University Party /n Written by: GPT2-medium /n Cohen Produced by: Robert Carlock & Wendy Knoller [Scene: McMaster University Student Center. Rachel and Joey are talking] Joey: We're like, "We want to make some noise. And we're gonna sing." (beat) Rachel: You guys did a fantastic job of it! (beat) And you guys even talked to the president! (beat) And he said he wants us to try again next year! That's awesome! Joey: I was so worried!
#
# [Scene: Professor Ponder's office] Ponder: Whoops! No students came into my office. Joey: So we had to do something! Rachel: You did great!
#
# [Scene: Principal's office] Principal: Joey? What's the problem? Joey: We're really bored with the dance party. Principal: Well, I've been told that dance parties are awful. Joey: Really? How can you be mad? You guys have been dancing for eight minutes straight!
#
# [Scene: Principal's office] Principal: The dance was great. How did you like it? Joey: It was great! Principal: It was fun. Joey: We were all so nervous!
#
# [Scene: Professor Ponder's office] Ponder: You guys should make a party out of this year! I want to do this again next year! We should get a dance party! We sorry, we didn't. Rachel: It's a very sad day for our country.
#
# . Rachel: You guys did a fantastic job of it! (beat) And you guys even talked to the president! Joey: We're sorry, we didn't. Rachel: It's a very sad day for our country. Joey: It was great, I was proud of them!
#
# Episode 13 [ edit ]
#
# In a room in The Simpsons apartment in The Parking Lot, Homer is looking through a drawer when his doorbell rings, and the caller asks if he's going to be there later. When he answers he sees a man in a yellow, hoodie and black turtleneck and jeans walking away from the front door, which is unlocked. The guy opens Homer's door, and Homer begins to walk in. He's wearing the same black hoodie and jeans that Lisa wore when she took the bath and the same brown sweater and jacket that Bart wore when he went to class. When he walks through the front door, he looks out the door and sees a crowd of about 50 people. One of the men, dressed in a baseball cap and white shirt, stops, and says, "It's me." The guy then says to Homer, with a beard named The President. Homer, who thinks he has a secret, gives the president a kiss and runs out. When he turns around to see the president, he recognizes him as Rick. He asks him about his daughter. Homer says he didn't expect her to be in the United States so soon, and Rick says she has been to New York City and knows everything about the country and what's happening. Homer asks the President how he learned what he's talking about. The President tells Homer that he doesn't know why Homer wanted to find him out, but that he didn't really believe Homer was real and that's why he went to Springfield so early. Homer says he's not a monster, he just wants answers. The President: (to Homer) You know, you'll find answers, Mr. Bartlet. (looks down at his glasses) Homer: No, no, no. The President: Well, you got those, didn't you? Homer: (to the President) You know... they're just glasses. (sighs) Homer: It's over now. The President: No one's getting hurt, I promise. Homer: And I got a pretty good feeling about this guy.
#
# (When the Simpsons are Mr. President. Homer turns and sees Mr. Bartlet coming into the room, with a gun. Homer: (suddenly scared) Oh my God, what are you going to do? Mr. Bartlet: (thinks for a moment) What are you gonna do, Homer? Homer: I can't be with you anymore. You don't understand. (he stands up) I'm... I'm leaving! Mr. Bartlet: (in a frightened tone) Don't you know what I've been through? (they both look at each other, then back to each other) You want to know what it's like, Mr. President? (they look at each other again) It's the same to me. You wanna know what it's like to have a girlfriend? (they look at each other again) To have a girl you love, (they look at each other again) To have a guy you love, Homer, you can be with someone else. (they look at each other) You don't understand? Mr. President: What I'm really trying to tell you is that there's nothing more important to me than you and your love for me, (he looks at her with a look of determination) I'm just not He gets up to check the door. Homer: (turns around) Oh hey there, there's the President, he says he's not coming back tonight. (beat) What's wrong? Homer: (to his daughter) I thought you wanted to be home with me tonight. (beat) Oh, hey there, you got to go get me dinner, it's not ready yet. Homer: (tries to walk away) Mom, I got this. Mom: (tries to take him to bed) Why? Homer: (to his daughter) I said I'm gonna give you a gift. (she says it's about a snake, so he walks off with her) Homer: (laughs) You don't think I'm crazy. I think I'm really doing something right. Homer: I know you can do better than that! The Simpsons have returned home. It's Homer Simpson in his office, wearing his new hat, shirt and tie . Homer's face is red. He says, " I think I was so close! . You know, it's nice to have a normal father and normal mom ." He says, "But you know what? The world's better without me. . I guess they just don't like me anymore a normal day again." (gets up, walks over to Lisa and shakes her hand, then walks off ) Homer: So, what happened? What does it matter? It's all over, I'm going home. He steps out into the hall and turns on the television screen. He sees the logo of a motorcycle and calls out. Homer: Homer, I hope you haven't made any mistakes , it's always fun to see what other people think of me. The President: No, you didn't just get rid of your old boss? Homer: Heh, heh, it's like that when you're a kid . You're never happy . Homer is watching the news on the screen. He looks back at the Simpson house and sees someone talking to the president about this new gun control legislation. Homer: You know what they want? Homer turns to look at the president. The president: Oh, Homer, it's a shame you're not able to have a normal day anymore, but I'll see you in New Mexico. Homer: But we were talking about that, right? Homer gets on his bike and begins to cycle down the street. He is stopped in front of a barbershop. Homer: Hey, hey, I'm gonna go back day again. Homer: This is the best day of my life. Homer: So what? What am I going to do, play video games all day? Homer: Don't call me, Homer. It's not my place to tell you what to do . The president: But if you want me to, Homer , then just leave me alone. Homer: Whoa, no. I'm sorry, I didn't mean it that way. I'll be back . (throws the gun under the table) Homer: What? Whoa, no, no. (turns on his television) I know, I know, I'm sorry . (holds the television down) I know, I'm sorry, I know, I'm sorry . Homer: (furious) What is this, what are you trying to do, Mr. President? You've got a very good idea , just wait 'til I get there , then you'll see . The president: What? Homer: (he picks up his television) I'm not gonna tell you what to do, just leave me alone . (he puts it back down )
#
# Homer: (after being shot and dying in Homer's home) I'm sorry, (gets up) you know . It's a shame, but I don't have time to talk to you. Homer: I'm only sorry you didn't get there in time to help. The president: That's exactly what we're going to do. (sees Homer in his office) Well, you know what I mean, now you can tell me. Homer: ...I didn't know that. The president: No? Well, let's see, Homer has this gun that shoots bullets, you have your plan , we've got ours. Homer: Okay, well, you see, you never said I could get the guns, you said I could stop you, so that means you'll just have to get the gun. (Homer stands) This guy says, "The president's gun has been put into a safe, Homer Simpson and the Simpson family are safe in the White House." Homer: (grins) No! (hangs his head down) I'm not a monster! I'm a man! Homer: (hangs his head) Well, I don't have any other plans, and you know what else, I'm sorry to have to tell you this, but we've got no money, we've got nowhere to go, and I've

# %%
file_name = "generated_script_with_summary.txt"
file_path = os.path.join(output_dir, file_name)

os.makedirs(output_dir, exist_ok=True)
with open(file_path, "w") as f:
    f.write(generated_script_with_summary)
print(f"File saved to: {file_path}")
# Out:
# File saved to: /content/drive/MyDrive/SEP775NLP_Final_Project/Models/Falconsai/generated_script_with_summary.txt

# %%
guides = [
    "Rachel:",
    "Monica:",
    "Phoebe:",
    "Joey:",
    "Chandler:",
    "Ross:"
]
# create initial prompt and tokenize it
prompt = "The One With McMaster University Party /n Written by: GPT2-medium /n Cohen Produced by: Robert Carlock & Wendy Knoller [Scene: McMaster University Student Center. Rachel and Joey are talking] Joey:"
model_inputs = tokenizer(prompt, return_tensors="pt", return_attention_mask=True).to(model.device)
model.generation_config.pad_token_id = tokenizer.pad_token_id # suppress padding warning

# create a list that holds the prompt, future tokens will be appended into this list later on
all_tokens = model_inputs["input_ids"][0].tolist()

# to avoid hitting memory limits, generate only one batch with the initial prompt, take last few tokens out to generate the next batch.
context_window = 256 # take this many tokens to set up next batch's generation
max_token = 2048
step_size = 256 # generate only 256 new tokens at a time
num_of_loops = int(max_token / step_size)

for i in range(num_of_loops):

  output = model.generate(**model_inputs,
                          max_new_tokens=step_size,
                          do_sample=True,
                          top_k=50, # keep 50 highest probable options
                          top_p=0.9, # keep only the options that add up to p% probability, filter out the remaining less probable options
                          temperature=1) # to add a little bit more creativity if needed

  output_tokens = output[0].tolist()

  new_tokens = output_tokens[-step_size:] # get rid of the previous context and keep only new tokens
  all_tokens.extend(new_tokens) # and place those tokens into the list




  current_text = tokenizer.decode(all_tokens, skip_special_tokens=True)
  summary = summarize_long_text(current_text)

  recent_part = tokenizer.decode(all_tokens[-40:], skip_special_tokens=True)

  new_prompt = summary + "\n\n" + recent_part.strip() + "\n\n" + random.choice(guides)
  model_inputs = tokenizer(new_prompt, return_tensors="pt", return_attention_mask=True).to(model.device)




  # previous_context = output_tokens[-context_window:] # set new previous_context for next loop
  # previous_context_tensor = torch.tensor([previous_context]).to(model.device) # prepare the inputs and attention mask for next loop
  # attention_mask = (previous_context_tensor != tokenizer.pad_token_id).long()
  # model_inputs = {"input_ids": previous_context_tensor, "attention_mask":attention_mask}



# decode from the list and print results
generated_script_with_summary_guide = tokenizer.decode(all_tokens, skip_special_tokens=True)
print("-------------------------------------------------------------")
print(generated_script_with_summary_guide)
# Out:
# -------------------------------------------------------------
# The One With McMaster University Party /n Written by: GPT2-medium /n Cohen Produced by: Robert Carlock & Wendy Knoller [Scene: McMaster University Student Center. Rachel and Joey are talking] Joey: You're saying we're crazy? Rachel: Yeah, you're just as crazy. I mean, do you realize how much of that stuff is just so... It's just bullshit. Joey: No, I mean, we're not crazy. We're just the ones who like it. You have a sense of humor. Rachel: Oh my God, I mean... But we're not gonna leave the world like this. That's why I'm going to start doing it. And you know why? Because I don't want you to go back to the old, old world of doing this shit like... [Shouts.] Joey: You don't even wanna go back to this shit, Rachel? Rachel: I'm not gonna go back to it! I'm gonna do it! It's okay! You can just stop thinking about it! You don't want to hear about it, you know? You don't want to hear about us doing stuff like this. It's not the same thing! Joey: Yeah, it's not. Rachel: We're gonna put the band back together, you see? That's the idea. You know why? Because... I don't wanna lose my job. I wanna do my dream job, you know? I'm doing What do you mean? Rachel: I know, the guy's a fucking jerk! He never takes the time to give a fuck.
#
# Rox: ...that you've been so adamant about. Joey: You're the one that's gonna go to his death. You know it's a possibility that the
#
# "The Last Call"
#
# Rox: No! I don't wanna! I don't wanna! She's right. It's the most stupid thing I've ever seen. That's the last
#
# time I can remember watching "The Last Call." And I think I just... The worst part was when she said "the
#
# ... The last time I can remember watching "The Last Call." And I think I just...
#
# Hannah: You know, I don't even know about you but I'm going to
#
# ... You know, I don't even know about you but I'm going to give myself a little break this week because of my
#
# ... And then I'm going to have my fun. But, uh, I guess, when the time comes I'll see how far I can go. And
#
# "... You know, I don't even know about you but I'm going to give myself So is she just stupid? What about when she told you to get
#
# Rox: Well, why does she call me "little Joey"? Joey: I said you had an
#
# Joey: You know what you just did? You just put your hand up your pants
#
# and you took out a gun. She just goes "You know what? I'll take that." And you
#
# "Well you have my money. I'll go get my car." She just goes "Well that's fine" and
#
# Joey: Is she going to shoot at me? Is she going to shoot at me? Rox: (laughing) she's a bad bitch. If I'd done the thing
#
# Joey: (shaking his head) no way. Rox: No I'm going to do the thing.
#
# Joey: (laughing)
#
# Rox: And I guess she's kind of crazy. (laughing) She's like - what's up, how are
#
# Joey: I don't see what she is. (laughing)
#
# Rox: (laughs) she's got this whole thing going on. She's like this - she's like she has this whole thing (shaking her head) Well I don't know about that.
#
# Rachel: I'm like yeah I think you should try and be as cool as possible like that and then try and take out this dude and be like okay okay, he's got a little bit of a personality. I mean, he was the same, he was cool. He was the same kid with the same hair, he was the same. So yeah you should try and be cool, like that.
#
# "Oh My God, You're So Nice"
#
# (At the end of the episode, Rox is sitting in her car with another fan.)
#
# Rox: Hi everybody. I'm Rox. I love being an actor. I've done a few things. I've done several things. And then I'm about to be a mom for the first time. So you guys...I would just like to just be very polite. But I know that I look fabulous.
#
# Mia: Oh, Rox! You look fantastic!
#
# (The camera pans to her.)
#
# Mia: Rox - we were watching this really bad film in the theater. It's a film about two people who were separated by death. But after one of them goes What?
#
# Rox: And they meet up on the other side of the country. Rachel: No. That film is made
#
# to look like it's about a dead woman. That's so
#
# fucking dumb.
#
# Rox: Well, if that's what you're gonna watch, I'll let you watch it.
#
# Mia: We're the ones who're going to watch it. We were watching that in the
#
# chamber, and I had this really great thought, "How could I get her to watch this movie and she
#
# likes it?" So I just... it's a really good thing that you're there and
#
# we got to get out of here. I was gonna come back but
#
# there's no way I'm going to come back
#
# if you can't. We're gonna come back!
#
# Rachel: You're going to
#
# take us!
#
# Rox: Don't... don't you want to see this movie? I'm not gonna watch
#
# it if you're gonna take us! She's right. If you're
#
# talking to me, you can't really take us because she can see it. She
#
# can.
#  It's about a party gone wrong . Joey: Yeah, but if we're gonna have a party . Phoebe: Well that's just like the idea . Joey: The thing I really don't like about this movie is that it's basically an action movie without even talking about any of that . It's like the idea . Phoebe: I like the idea but if I can watch the movie a few more times then that I'll appreciate it . Joey: You know what? It's so bad that I just can't. Phoebe: We can just sit and watch it together , Joey, and we'll talk about what's the point of all this .
#
# Rachel: Oh, I got something I want to talk to you about. I think we should call it the " I got something I want to talk to you about. I think we should call it the " Phoebe Fallacy ". It was created by the actor George Clooney . He's a huge celebrity and you would think his opinion on The One With McMaster University Party /n , would be an obvious one, but he doesn't really say anything in that episode, he just kinda tells his story and I think he's just trying to do the best he can. He I think this is the best one
#
# Rachel: This is the best!
#
# A.V.: I'm gonna call it the "Phoebe Fallacy", actually, because it's basically "how can you not think of Phoebe as your friend?" But this is what they came up with, and it's hilarious to watch. I'd argue that it's an awesome, fun bit, but I don't know if you've seen it before, so I'll try and explain how this works in the comments!The scene that's been the most talked about lately, I think, is the episode where Phoebe and Joey finally get together . In fact, it was probably the scene where they finally got together , at which point Phoebe said "Well, we could just call it 'The One with the Big Bang Theory Party.' "But, that's not the way it ends, is it? We can't call that "the One with the One With the Big Bang Theory Party." It'll just be this weird double-episode thing , and I think Phoebe might be the one who feels like she can't do anything with this. But then we've got this whole thing in "I Am Phoebe" and it Well, the only thing I've ever seen
#
# A: Oh my God!
#
# B: That scene was really fun . I remember having a lot of fun . So it's nice to finally have a new episode. So when the new episode comes out, it will probably be kind of like, "I am a phoebe"
#
# Rachel and Joey's story is very similar. Phoebe starts out as a weird character with weird personality and I mean we're already in an episode where she's doing weird things and it's a cool thing to be able to share your story . We have so many moments of her doing things like being an introvert and being a weird introvert in an episode. So, when we've got that little moment, it's good to share that with the audience.
#
# In my opinion, Rachel is going to be the best character of this season. Rachel: I like to call my character Phoebe and my personality Phoebe: [chuckles] Rachel: You have to call your personality Phoebe because my personality Phoebe . It's that easy . You call it Rachel: Phoebe Ross: You're Phoebe Ross: Yeah, well, that's Phoebe!

# %%
file_name = "generated_script_with_summary_guide.txt"
file_path = os.path.join(output_dir, file_name)

os.makedirs(output_dir, exist_ok=True)
with open(file_path, "w") as f:
    f.write(generated_script_with_summary_guide)
print(f"File saved to: {file_path}")
# Out:
# File saved to: /content/drive/MyDrive/SEP775NLP_Final_Project/Models/Falconsai/generated_script_with_summary_guide.txt
